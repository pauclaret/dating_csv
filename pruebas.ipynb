# %%
import chardet
import pandas as pd
import numpy as np

# %%
with open('speeddating.csv', 'rb') as f:
    enc = chardet.detect(f.read())  
    
df_dating = pd.read_csv('speeddating.csv', encoding = enc['encoding'])
df_dating.head()
# Out:
#    iid   id  gender  idg  condtn  wave  round  position  positin1  order  ...  \
# 0    1  1.0       0    1       1     1     10         7       NaN      4  ...
# 1    1  1.0       0    1       1     1     10         7       NaN      3  ...
# 2    1  1.0       0    1       1     1     10         7       NaN     10  ...
# 3    1  1.0       0    1       1     1     10         7       NaN      5  ...
# 4    1  1.0       0    1       1     1     10         7       NaN      7  ...
#
#    attr3_3  sinc3_3  intel3_3  fun3_3  amb3_3  attr5_3  sinc5_3  intel5_3  \
# 0      5.0      7.0       7.0     7.0     7.0      NaN      NaN       NaN
# 1      5.0      7.0       7.0     7.0     7.0      NaN      NaN       NaN
# 2      5.0      7.0       7.0     7.0     7.0      NaN      NaN       NaN
# 3      5.0      7.0       7.0     7.0     7.0      NaN      NaN       NaN
# 4      5.0      7.0       7.0     7.0     7.0      NaN      NaN       NaN
#
#    fun5_3  amb5_3
# 0     NaN     NaN
# ...

# %%
pd.options.display.max_columns = None

# %%
df_dating.sample(10)
# Out:
#       iid    id  gender  idg  condtn  wave  round  position  positin1  order  \
# 3034  215   2.0       1    4       2     9     20        18       3.0     16
# 2158  158   1.0       1    2       2     7     16         2       9.0     10
# 2557  188   5.0       1   10       1     8     10         3       2.0      2
# 3023  214   1.0       1    2       2     9     20        20       5.0     16
# 1998  148   7.0       0   13       2     7     16         2       2.0     15
# 2940  210  17.0       0   33       2     9     20         1       1.0      1
# 2069  152  11.0       0   21       2     7     16        12      12.0     12
# 2444  177   4.0       0    7       1     8     10         4       4.0      9
# 2653  196   3.0       0    5       2     9     20         5       5.0      4
# 1913  143   2.0       0    3       2     7     16        10      10.0      3
#
#       partner    pid  match  int_corr  samerace  age_o  race_o  pf_o_att  \
# ...

# %%
df_dating.head(30)
# Out:
#       iid   id  gender  idg  condtn  wave  round  position  positin1  order  \
# 1846  132  1.0       0    1       1     6      5         2       2.0      5
# 1847  132  1.0       0    1       1     6      5         2       2.0      2
# 1848  132  1.0       0    1       1     6      5         2       2.0      3
# 1849  132  1.0       0    1       1     6      5         2       2.0      4
# 1850  132  1.0       0    1       1     6      5         2       2.0      1
# 1851  133  2.0       0    3       1     6      5         3       3.0      1
# 1852  133  2.0       0    3       1     6      5         3       3.0      3
# 1853  133  2.0       0    3       1     6      5         3       3.0      4
# 1854  133  2.0       0    3       1     6      5         3       3.0      5
# 1855  133  2.0       0    3       1     6      5         3       3.0      2
# 1856  134  3.0       0    5       1     6      5         4       4.0      2
# ...

# %%
df_dating.columns
# Out:
# Index(['iid', 'id', 'gender', 'idg', 'condtn', 'wave', 'round', 'position',
#        'positin1', 'order',
#        ...
#        'attr3_3', 'sinc3_3', 'intel3_3', 'fun3_3', 'amb3_3', 'attr5_3',
#        'sinc5_3', 'intel5_3', 'fun5_3', 'amb5_3'],
#       dtype='object', length=195)

# %%
df_dating.dtypes
# Out:
# iid           int64
# id          float64
# gender        int64
# idg           int64
# condtn        int64
#              ...
# attr5_3     float64
# sinc5_3     float64
# intel5_3    float64
# fun5_3      float64
# amb5_3      float64
# Length: 195, dtype: object

# %%
df_dating.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8378 entries, 0 to 8377
# Columns: 195 entries, iid to amb5_3
# dtypes: float64(174), int64(13), object(8)
# memory usage: 12.5+ MB

# %%
df_dating.describe().T
# Out:
#            count        mean         std  min    25%    50%    75%    max
# iid       8378.0  283.675937  158.583367  1.0  154.0  281.0  407.0  552.0
# id        8377.0    8.960248    5.491329  1.0    4.0    8.0   13.0   22.0
# gender    8378.0    0.500597    0.500029  0.0    0.0    1.0    1.0    1.0
# idg       8378.0   17.327166   10.940735  1.0    8.0   16.0   26.0   44.0
# condtn    8378.0    1.828837    0.376673  1.0    2.0    2.0    2.0    2.0
# ...          ...         ...         ...  ...    ...    ...    ...    ...
# attr5_3   2016.0    6.810020    1.507341  2.0    6.0    7.0    8.0   10.0
# sinc5_3   2016.0    7.615079    1.504551  2.0    7.0    8.0    9.0   10.0
# intel5_3  2016.0    7.932540    1.340868  4.0    7.0    8.0    9.0   10.0
# fun5_3    2016.0    7.155258    1.672787  1.0    6.0    7.0    8.0   10.0
# amb5_3    2016.0    7.048611    1.717988  1.0    6.0    7.0    8.0   10.0
#
# [187 rows x 8 columns]

# %%
df_dating.describe(include = "object").T
# Out:
#          count unique          top freq
# field     8315    259     Business  521
# undergra  4914    241  UC Berkeley  107
# mn_sat    3133     68     1,400.00  403
# tuition   3583    115    26,908.00  241
# from      8299    269     New York  522
# zipcode   7314    409            0  355
# income    4279    261    55,080.00  124
# career    8289    367      Finance  202

# %%
df_dating.columns
# Out:
# Index(['iid', 'id', 'gender', 'idg', 'condtn', 'wave', 'round', 'position',
#        'positin1', 'order',
#        ...
#        'attr3_3', 'sinc3_3', 'intel3_3', 'fun3_3', 'amb3_3', 'attr5_3',
#        'sinc5_3', 'intel5_3', 'fun5_3', 'amb5_3'],
#       dtype='object', length=195)

# %%
df_dating.isnull().sum()
# Out:
# iid            0
# id             1
# gender         0
# idg            0
# condtn         0
#             ...
# attr5_3     6362
# sinc5_3     6362
# intel5_3    6362
# fun5_3      6362
# amb5_3      6362
# Length: 195, dtype: int64

# %%
df_dating.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8373    False
# 8374    False
# 8375    False
# 8376    False
# 8377    False
# Length: 8378, dtype: bool

# %%
df_dating.columns
# Out:
# Index(['iid', 'id', 'gender', 'idg', 'condtn', 'wave', 'round', 'position',
#        'positin1', 'order',
#        ...
#        'attr3_3', 'sinc3_3', 'intel3_3', 'fun3_3', 'amb3_3', 'attr5_3',
#        'sinc5_3', 'intel5_3', 'fun5_3', 'amb5_3'],
#       dtype='object', length=195)

# %%
values = [6,7,8,9]

# %%
df_dating = df_dating[df_dating.wave.isin(values) == True]

# %%
df_dating.sample(30)
# Out:
#       iid    id  gender  idg  condtn  wave  round  position  positin1  order  \
# 2341  169  12.0       1   24       2     7     16         5       5.0      1
# 3208  224  11.0       1   22       2     9     20         2      20.0      3
# 2294  166   9.0       1   18       2     7     16         7       2.0      6
# 2692  198   5.0       0    9       2     9     20        14      14.0     16
# 2253  164   7.0       1   14       2     7     16         3       4.0     16
# 2822  204  11.0       0   21       2     9     20        17      17.0      9
# 2046  151  10.0       0   19       2     7     16         6       6.0      3
# 3122  219   6.0       1   12       2     9     20        15       2.0     14
# 2201  161   4.0       1    8       2     7     16        10       7.0      4
# 2496  182   9.0       0   17       1     8     10         6       6.0      8
# 3200  223  10.0       1   20       2     9     20        16      18.0     19
# ...

# %%
df_dating["wave"].unique()
# Out:
# array([6, 7, 8, 9], dtype=int64)

# %%
df_dating.shape
# Out:
# (1562, 195)

# %%
eliminate = ["id", "idg", "position", "positin1", "partner", "int_corr", "undergra", "mn_sat", "tuition", "zipcode", "income", "expnum", "satis_2", "length", "numdat_2", "attr7_2", "sinc7_2", "intel7_2", "fun7_2", "amb7_2", "shar7_2", "attr1_2", "sinc1_2", "intel1_2", "fun1_2", "amb1_2", "shar1_2", "attr4_2", "sinc4_2", "intel4_2", "fun4_2", "amb4_2", "shar4_2", "attr2_2", "sinc2_2", "intel2_2", "fun2_2", "amb2_2", "shar2_2", "attr3_2", "sinc3_2", "intel3_2", "fun3_2", "amb3_2", "attr5_2", "sinc5_2", "intel5_2", "fun5_2", "amb5_2", "attr1_3", "sinc1_3", "intel1_3", "fun1_3", "amb1_3", "shar1_3", "attr7_3", "sinc7_3", "intel7_3", "fun7_3", "amb7_3", "shar7_3", "attr4_3", "sinc4_3", "intel4_3", "fun4_3", "amb4_3", "shar4_3", "attr2_3", "sinc2_3", "intel2_3", "fun2_3", "amb2_3", "shar2_3", "attr3_3", "sinc3_3", "intel3_3", "fun3_3", "amb3_3", "attr5_3", "sinc5_3", "intel5_3", "fun5_3", "amb5_3"]

# %%
eliminate2 = ["dec_o", "attr5_1", "sinc5_1", "intel5_1", "fun5_1", "amb5_1", "attr1_s", "sinc1_s", "intel1_s", "fun1_s", "amb1_s", "shar1_s", "attr3_s", "sinc3_s", "intel3_s", "fun3_s", "amb3_s"]

# %%
eliminate3 = ["condtn", "round", "career", "career_c", "attr4_1", "sinc4_1", "intel4_1", "fun4_1", "amb4_1", "shar4_1", "attr2_1", "sinc2_1", "intel2_1", "fun2_1", "amb2_1", "shar2_1", "attr3_1", "sinc3_1", "fun3_1", "intel3_1", "amb3_1", "match_es", "you_call", "them_cal", "date_3", "numdat_3", "num_in_3"]

# %%
df_dating = df_dating.drop(eliminate3, axis = 1)

# %%
df_dating.head()
# Out:
#       iid  gender  wave  order    pid  match  samerace  age_o  race_o  \
# 1846  132       0     6      5  137.0      0         0   26.0     4.0
# 1847  132       0     6      2  138.0      0         1   32.0     2.0
# 1848  132       0     6      3  139.0      0         0   37.0     4.0
# 1849  132       0     6      4  140.0      1         1   29.0     2.0
# 1850  132       0     6      1  141.0      0         0   28.0     3.0
#
#       pf_o_att  pf_o_sin  pf_o_int  pf_o_fun  pf_o_amb  pf_o_sha  attr_o  \
# 1846     17.39     17.39     15.22     17.39     13.04     19.57     8.0
# 1847     20.00     20.00     20.00     20.00      6.67     13.33     8.0
# 1848     18.75     16.67     18.75     20.83     12.50     12.50     8.0
# 1849     18.60     16.28     18.60     18.60     11.63     16.28     7.0
# 1850     20.83     20.83     16.67     16.67      6.25     18.75     8.0
#
#       sinc_o  intel_o  fun_o  amb_o  shar_o  like_o  prob_o  met_o   age  \
# ...

# %%
df_dating.set_index('iid', inplace = True)

# %%
df_dating.head(70)
# Out:
#      gender  wave  order    pid  match  samerace  age_o  race_o  pf_o_att  \
# iid
# 132       0     6      5  137.0      0         0   26.0     4.0     17.39
# 132       0     6      2  138.0      0         1   32.0     2.0     20.00
# 132       0     6      3  139.0      0         0   37.0     4.0     18.75
# 132       0     6      4  140.0      1         1   29.0     2.0     18.60
# 132       0     6      1  141.0      0         0   28.0     3.0     20.83
# 133       0     6      1  137.0      0         1   26.0     4.0     17.39
# 133       0     6      3  138.0      0         0   32.0     2.0     20.00
# 133       0     6      4  139.0      0         1   37.0     4.0     18.75
# 133       0     6      5  140.0      0         0   29.0     2.0     18.60
# 133       0     6      2  141.0      0         0   28.0     3.0     20.83
# 134       0     6      2  137.0      1         0   26.0     4.0     17.39
# 134       0     6      4  138.0      0         1   32.0     2.0     20.00
# ...

# %%
df_dating.groupby(level=0)['match'].sum()
# Out:
# iid
# 132     1
# 133     0
# 134     1
# 135     2
# 136     1
# 137     1
# 138     1
# 139     0
# 140     2
# 141     1
# 142     7
# 143     0
# 144     1
# 145     0
# 146     1
# 147     5
# 148     1
# 149     5
# 150     2
# 151     2
# 152     3
# 153     3
# 154     7
# 155     1
# 156     4
# 157     1
# 158     0
# 159     2
# 160     3
# 161     2
# 162     2
# 163     3
# 164     2
# 165     3
# 166     3
# 167     3
# 168     1
# 169     5
# 170     0
# 171     4
# 172     5
# 173     5
# 174     2
# 175     3
# 176     3
# 177     0
# 178     1
# 179     1
# 180     2
# 181     5
# 182     0
# 183     1
# 184     4
# 185     1
# 186     3
# 187     1
# 188     1
# 189     0
# 190     3
# 191     2
# 192     1
# 193     2
# 194     1
# 195     5
# 196     2
# 197     3
# 198     0
# 199     5
# 200     3
# 201     1
# 202     2
# 203     0
# 204     0
# 205     2
# 206     8
# 207     3
# 208    11
# 209     0
# 210     3
# 211     2
# 212     9
# 213     2
# ...

# %%
df_dating.loc[[208]]
# Out:
#      gender  wave  order    pid  match  samerace  age_o  race_o  pf_o_att  \
# iid
# 208       0     9     11  214.0      0         0   23.0     2.0     17.02
# 208       0     9     13  215.0      1         0   26.0     4.0     14.89
# 208       0     9     20  216.0      0         0   27.0     2.0      7.50
# 208       0     9      6  217.0      1         0   26.0     2.0     21.28
# 208       0     9     17  218.0      0         0   24.0     2.0     20.51
# 208       0     9     14  219.0      1         0   26.0     2.0     16.28
# 208       0     9      2  220.0      1         0   25.0     6.0     16.67
# 208       0     9      9  221.0      0         0   27.0     4.0     15.56
# 208       0     9      4  222.0      0         0   27.0     2.0      9.52
# 208       0     9     18  223.0      0         0   28.0     2.0     17.39
# 208       0     9     16  224.0      1         0   32.0     2.0     17.24
# 208       0     9      1  225.0      0         0   28.0     3.0     14.71
# ...
